# %%
import os

import itertools
import collections

import pandas as pd
import matplotlib.pyplot as plt

import community
import networkx as nx

# %%
df_allegations = pd.read_csv('results_victimrace_officer_allegations.csv')

# %%
df_allegations.head()
# Out:
#    allegation_id  officer_id    final_outcome                     allegation  \
# 0          27716       22414  No Action Taken  Illegal Arrest / False Arrest
# 1          27716       22414  No Action Taken  Illegal Arrest / False Arrest
# 2          27716        9389  No Action Taken  Illegal Arrest / False Arrest
# 3          27716        9389  No Action Taken  Illegal Arrest / False Arrest
# 4          27716        7423  No Action Taken  Illegal Arrest / False Arrest
#
#   victim_race
# 0   Not found
# 1   Not found
# 2   Not found
# 3   Not found
# 4   Not found

# %%
df_allegations = df_allegations[df_allegations['victim_race'] == 'Black']

# %%
df_allegations.head()
# Out:
#     allegation_id  officer_id    final_outcome     allegation victim_race
# 45          27721       12640  No Action Taken  Miscellaneous       Black
# 46          27721       12640  No Action Taken  Miscellaneous       Black
# 47          27721       12212  No Action Taken  Miscellaneous       Black
# 48          27721       12212  No Action Taken  Miscellaneous       Black
# 49          27721        7712  No Action Taken  Miscellaneous       Black

# %%
len(df_allegations)
# Out:
# 78592

# %%
df_officer_allegations = df_allegations[['officer_id', 'allegation']]

# %%
df_officer_allegations = df_officer_allegations.groupby('officer_id')['allegation'].apply(list)

# %%
def generate_edges(list_of_alleg):
    return [(list_of_alleg[i], list_of_alleg[i+1])for i in range(0,len(list_of_alleg)-1)]

# %%
edges = []

for row in df_officer_allegations:
    count = len(row)
    if count > 1:
        edges.extend(generate_edges(row))

# %%
edges
# Out:
# [('Unnecessary Display Of Weapon / Off Duty',
#   'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant',
#   'Inadequate / Failure To Provide Service'),
#  ('Inventory Procedures', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury', 'Gang Affiliation'),
#  ('Gang Affiliation', 'Gang Affiliation'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Prisoners Property', 'Miscellaneous'),
#  ('Miscellaneous', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury', 'Arrest, Improper Procedures'),
#  ('Arrest, Improper Procedures', 'Arrest, Improper Procedures'),
#  ('Arrest, Improper Procedures', 'Arrest, Improper Procedures'),
#  ('Arrest, Improper Procedures', 'Arrest, Improper Procedures'),
#  ('Arrest, Improper Procedures', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Miscellaneous'),
#  ('Miscellaneous', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Use Of Profanity'),
#  ('Use Of Profanity', 'Use Of Profanity'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Inadequate / Failure To Provide Service'),
#  ('Excessive Force - Use Of Firearm / Off Duty - No Injury',
#   'Excessive Force - Use Of Firearm / Off Duty - No Injury'),
#  ('Excessive Force - Use Of Firearm / Off Duty - No Injury',
#   'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Reports'),
#  ('Reports', 'Reports'),
#  ('Improper Detention', 'Improper Detention'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Neglect Of Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Search - Person / Property'),
#  ('Search - Person / Property', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Unnecessary Display Of Weapon / Off Duty'),
#  ('Unnecessary Display Of Weapon / Off Duty',
#   'Unnecessary Display Of Weapon / Off Duty'),
#  ('Unnecessary Display Of Weapon / Off Duty',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Seat Belts', 'Seat Belts'),
#  ('Unnecessary Display Of Weapon / Off Duty',
#   'Unnecessary Display Of Weapon / Off Duty'),
#  ('Unnecessary Display Of Weapon / Off Duty',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Use Of Profanity', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Improper Search Of Vehicle'),
#  ('Improper Search Of Person', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Racial Profiling', 'Racial Profiling'),
#  ('Racial Profiling', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Prisoners Property'),
#  ('Prisoners Property', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Illegal Arrest / False Arrest', 'Miscellaneous'),
#  ('Miscellaneous', 'Reports'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Illegal Arrest / False Arrest'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Miscellaneous'),
#  ('Miscellaneous', 'Miscellaneous'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Inadequate / Failure To Provide Service'),
#  ('Improper Search Of Vehicle', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Neglect Of Duty'),
#  ('Inadequate / Failure To Provide Service',
#   'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury', 'Prisoners Property'),
#  ('Prisoners Property', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Domestic Incident - Not Physical'),
#  ('Domestic Incident - Not Physical', 'Domestic Incident - Not Physical'),
#  ('Domestic Incident - Not Physical', 'Domestic Incident - Not Physical'),
#  ('Domestic Incident - Not Physical', 'Domestic Incident - Not Physical'),
#  ('Domestic Incident - Not Physical', 'Miscellaneous'),
#  ('Miscellaneous', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury', 'Prisoners Property'),
#  ('Prisoners Property', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Inadequate / Failure To Provide Service'),
#  ('Slow / No Response', 'Improper Processing / Reporting / Procedures'),
#  ('Improper Processing / Reporting / Procedures',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Miscellaneous', 'Miscellaneous'),
#  ('Domestic Incident - Not Physical', 'Domestic Incident - Not Physical'),
#  ('Domestic Incident - Not Physical', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Prisoners Property'),
#  ('Prisoners Property', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Improper Search Of Person'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Escape'),
#  ('Escape', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury', 'Slow / No Response'),
#  ('Slow / No Response', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Damage / Trespassing To Property'),
#  ('Damage / Trespassing To Property', 'Damage / Trespassing To Property'),
#  ('Damage / Trespassing To Property', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Domestic Incident - Not Physical', 'Domestic Incident - Not Physical'),
#  ('Domestic Incident - Not Physical', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Neglect Of Duty'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury', 'Prisoners Property'),
#  ('Prisoners Property', 'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Illegal Arrest / False Arrest'),
#  ('Improper Search Of Person', 'Prisoners Property'),
#  ('Prisoners Property', 'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Improper Search Of Vehicle'),
#  ('Improper Processing / Reporting / Procedures', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Inadequate / Failure To Provide Service'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Improper Processing / Reporting / Procedures'),
#  ('Prisoners Property', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Take Down (Thrown To Ground)'),
#  ('Take Down (Thrown To Ground)', 'Take Down (Thrown To Ground)'),
#  ('Take Down (Thrown To Ground)',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Inadequate / Failure To Provide Service'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Inventory Procedures'),
#  ('Eeo Investigations', 'Eeo Investigations'),
#  ('Eeo Investigations', 'Eeo Investigations'),
#  ('Eeo Investigations', 'Eeo Investigations'),
#  ('Search Of Premise Without Warrant', 'Proper Care - Injury / Death'),
#  ('Proper Care - Injury / Death', 'Proper Care - Injury / Death'),
#  ('Proper Care - Injury / Death', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Miscellaneous', 'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Excessive Force - Use Of Firearm / Off Duty - No Injury', 'Miscellaneous'),
#  ('Miscellaneous', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Improper Processing / Reporting / Procedures'),
#  ('Improper Processing / Reporting / Procedures',
#   'Improper Processing / Reporting / Procedures'),
#  ('Improper Processing / Reporting / Procedures',
#   'Inadequate / Failure To Provide Service'),
#  ('Inventory Procedures', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Telephone / Attorney / Relative Privileges', 'Reports'),
#  ('Slow / No Response', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Inadequate / Failure To Provide Service', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Prisoners Property'),
#  ('Prisoners Property', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Slow / No Response'),
#  ('Slow / No Response', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Improper Search Of Vehicle', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Improper Search Of Person', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Miscellaneous'),
#  ('Miscellaneous', 'Illegal Arrest / False Arrest'),
#  ('Neglect Of Duty', 'Neglect Of Duty'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Unnecessary Display Of Weapon / Off Duty',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Improper Search Of Person', 'Improper Search Of Person'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Miscellaneous'),
#  ('Miscellaneous', 'Miscellaneous'),
#  ('Miscellaneous', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Excessive Force - Use Of Firearm / Off Duty - No Injury'),
#  ('Excessive Force - Use Of Firearm / Off Duty - No Injury',
#   'Excessive Force - Use Of Firearm / Off Duty - No Injury'),
#  ('Excessive Force - Use Of Firearm / Off Duty - No Injury',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Escape'),
#  ('Escape', 'Sexual Orientation'),
#  ('Sexual Orientation', 'Sexual Orientation'),
#  ('Sexual Orientation', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Neglect Of Duty'),
#  ('Miscellaneous', 'Miscellaneous'),
#  ('Miscellaneous', 'Miscellaneous'),
#  ('Miscellaneous', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Search Of Premise Without Warrant'),
#  ('Miscellaneous', 'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Miscellaneous', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Inadequate / Failure To Provide Service', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Domestic Incident - Not Physical'),
#  ('Domestic Incident - Not Physical', 'Domestic Incident - Not Physical'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Prisoners Property'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Unnecessary Display Of Weapon / Off Duty'),
#  ('Unnecessary Display Of Weapon / Off Duty',
#   'Unnecessary Display Of Weapon / Off Duty'),
#  ('Unnecessary Display Of Weapon / Off Duty', 'Prisoners Property'),
#  ('Prisoners Property', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Unnecessary Display Of Weapon / Off Duty'),
#  ('Unnecessary Display Of Weapon / Off Duty',
#   'Unnecessary Display Of Weapon / Off Duty'),
#  ('Unnecessary Display Of Weapon / Off Duty', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Use Of Profanity'),
#  ('Use Of Profanity', 'Use Of Profanity'),
#  ('Use Of Profanity', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle',
#   'Excessive Force - Use Of Firearm / Off Duty - No Injury'),
#  ('Excessive Force - Use Of Firearm / Off Duty - No Injury',
#   'Excessive Force - Use Of Firearm / Off Duty - No Injury'),
#  ('Excessive Force - Use Of Firearm / Off Duty - No Injury',
#   'Inadequate / Failure To Provide Service'),
#  ('Search Of Premise Without Warrant',
#   'Inadequate / Failure To Provide Service'),
#  ('Slow / No Response', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Inadequate / Failure To Provide Service',
#   'Misconduct During Issuance Of Citation'),
#  ('Misconduct During Issuance Of Citation',
#   'Misconduct During Issuance Of Citation'),
#  ('Misconduct During Issuance Of Citation', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Inventory Procedures', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Illegal Arrest / False Arrest', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Inadequate / Failure To Provide Service'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Improper Search Of Vehicle'),
#  ('Illegal Arrest / False Arrest', 'Sexual Orientation'),
#  ('Sexual Orientation', 'Sexual Orientation'),
#  ('Sexual Orientation', 'Altercation / Disturbance - Other'),
#  ('Altercation / Disturbance - Other', 'Altercation / Disturbance - Other'),
#  ('Altercation / Disturbance - Other',
#   'Improper Processing / Reporting / Procedures'),
#  ('Improper Processing / Reporting / Procedures',
#   'Inadequate / Failure To Provide Service'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Prisoners Property', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Racial / Ethnic, Etc.'),
#  ('Racial / Ethnic, Etc.', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Miscellaneous'),
#  ('Miscellaneous', 'Miscellaneous'),
#  ('Eeo Investigations', 'Eeo Investigations'),
#  ('Eeo Investigations', 'Unfit For Duty'),
#  ('Unfit For Duty', 'Unfit For Duty'),
#  ('Unfit For Duty', 'Miscellaneous'),
#  ('Miscellaneous', 'Miscellaneous'),
#  ('Miscellaneous', 'Eeo Investigations'),
#  ('Eeo Investigations', 'Eeo Investigations'),
#  ('Eeo Investigations', 'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Neglect Of Duty'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Inadequate / Failure To Provide Service', 'Miscellaneous'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Proper Care - Injury / Death'),
#  ('Proper Care - Injury / Death', 'Proper Care - Injury / Death'),
#  ('Proper Care - Injury / Death', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Miscellaneous'),
#  ('Fail To Enforce Traffic Regulations',
#   'Fail To Enforce Traffic Regulations'),
#  ('Fail To Enforce Traffic Regulations', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Neglect Of Duty'),
#  ('Neglect Of Duty', 'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty', 'Slow / No Response'),
#  ('Slow / No Response', 'Prisoners Property'),
#  ('Prisoners Property', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Damage / Trespassing To Property', 'Damage / Trespassing To Property'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Miscellaneous'),
#  ('Miscellaneous', 'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant',
#   'Unnecessary Display Of Weapon / Off Duty'),
#  ('Unnecessary Display Of Weapon / Off Duty',
#   'Unnecessary Display Of Weapon / Off Duty'),
#  ('Unnecessary Display Of Weapon / Off Duty',
#   'Firearm Discharge With Hits - Handgun'),
#  ('Firearm Discharge With Hits - Handgun',
#   'Firearm Discharge With Hits - Handgun'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force - Use Of Firearm / Off Duty - No Injury'),
#  ('Excessive Force - Use Of Firearm / Off Duty - No Injury',
#   'Excessive Force - Use Of Firearm / Off Duty - No Injury'),
#  ('Excessive Force - Use Of Firearm / Off Duty - No Injury',
#   'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury',
#   'Unnecessary Physical Contact / On Duty - No Injury'),
#  ('Unnecessary Physical Contact / On Duty - No Injury', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Damage / Trespassing To Property', 'Damage / Trespassing To Property'),
#  ('Improper Search Of Person', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Improper Search Of Person'),
#  ('Miscellaneous', 'Miscellaneous'),
#  ('Miscellaneous', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Miscellaneous'),
#  ('Miscellaneous', 'Domestic Altercation - Physical Abuse'),
#  ('Domestic Altercation - Physical Abuse',
#   'Domestic Altercation - Physical Abuse'),
#  ('Domestic Altercation - Physical Abuse',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Slow / No Response'),
#  ('Slow / No Response', 'Inadequate / Failure To Provide Service'),
# ...
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Unnecessary Physical Contact / Off Duty - No Injury'),
#  ('Unnecessary Physical Contact / Off Duty - No Injury',
#   'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Miscellaneous'),
#  ('Miscellaneous', 'Miscellaneous'),
#  ('Miscellaneous', 'Damage / Trespassing To Property'),
#  ('Damage / Trespassing To Property', 'Damage / Trespassing To Property'),
#  ('Damage / Trespassing To Property', 'Damage / Trespassing To Property'),
#  ('Damage / Trespassing To Property', 'Damage / Trespassing To Property'),
#  ('Damage / Trespassing To Property', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Improper Search Of Person'),
#  ('Sexual Orientation', 'Sexual Orientation'),
#  ('Sexual Orientation', 'Prisoners Property'),
#  ('Prisoners Property', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Prisoners Property'),
#  ('Prisoners Property', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Slow / No Response'),
#  ('Slow / No Response', 'Slow / No Response'),
#  ('Slow / No Response', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Prisoners Property'),
#  ('Prisoners Property', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Miscellaneous'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Prisoners Property'),
#  ('Search Of Premise Without Warrant', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Theft'),
#  ('Theft', 'Theft'),
#  ('Theft', 'Theft'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Miscellaneous'),
#  ('Miscellaneous', 'Miscellaneous'),
#  ('Miscellaneous', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Miscellaneous', 'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Slow / No Response'),
#  ('Escape', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Reports'),
#  ('Reports', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Inadequate / Failure To Provide Service'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Reports'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Miscellaneous'),
#  ('Miscellaneous', 'Miscellaneous'),
#  ('Miscellaneous', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Damage / Trespassing To Property'),
#  ('Damage / Trespassing To Property', 'Damage / Trespassing To Property'),
#  ('Damage / Trespassing To Property', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Prisoners Property'),
#  ('Prisoners Property', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant',
#   'Excessive Force - Use Of Firearm / Off Duty - No Injury'),
#  ('Excessive Force - Use Of Firearm / Off Duty - No Injury',
#   'Excessive Force - Use Of Firearm / Off Duty - No Injury'),
#  ('Excessive Force - Use Of Firearm / Off Duty - No Injury',
#   'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Inventory Procedures'),
#  ('Inventory Procedures', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Improper Search Of Vehicle'),
#  ('Sexual Orientation', 'Sexual Orientation'),
#  ('Sexual Orientation', 'Prisoners Property'),
#  ('Prisoners Property', 'Arrest, Improper Procedures'),
#  ('Arrest, Improper Procedures', 'Arrest, Improper Procedures'),
#  ('Miscellaneous', 'Miscellaneous'),
#  ('Miscellaneous', 'Improper Search Of Person'),
#  ('Improper Search Of Person', 'Unnecessary Display Of Weapon / Off Duty'),
#  ('Unnecessary Display Of Weapon / Off Duty',
#   'Unnecessary Display Of Weapon / Off Duty'),
#  ('Unnecessary Display Of Weapon / Off Duty',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - No Injury'),
#  ('Excessive Force / On Duty - No Injury',
#   'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Excessive Force / On Duty - Injury',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service',
#   'Inadequate / Failure To Provide Service'),
#  ('Inadequate / Failure To Provide Service', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Illegal Arrest / False Arrest'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Inadequate / Failure To Provide Service', 'Miscellaneous'),
#  ('Domestic Incident - Not Physical', 'Domestic Incident - Not Physical'),
#  ('Inadequate / Failure To Provide Service',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Slow / No Response', 'Excessive Force / Off Duty - No Injury'),
#  ('Excessive Force / Off Duty - No Injury',
#   'Excessive Force / Off Duty - No Injury'),
#  ('Excessive Force / Off Duty - No Injury',
#   'Unnecessary Display Of Weapon / Off Duty'),
#  ('Unnecessary Display Of Weapon / Off Duty',
#   'Unnecessary Display Of Weapon / Off Duty'),
#  ('Misconduct During Issuance Of Citation',
#   'Misconduct During Issuance Of Citation'),
#  ('Misconduct During Issuance Of Citation', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Improper Search Of Vehicle', 'Improper Search Of Vehicle'),
#  ('Improper Search Of Vehicle', 'Fail To Obtain A Complaint Register Number'),
#  ('Fail To Obtain A Complaint Register Number',
#   'Fail To Obtain A Complaint Register Number'),
#  ('Excessive Force / On Duty - Injury', 'Excessive Force / On Duty - Injury'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty',
#   'Unnecessary Display Of Weapon / On Duty'),
#  ('Unnecessary Display Of Weapon / On Duty', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Illegal Arrest / False Arrest'),
#  ('Illegal Arrest / False Arrest', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ('Search Of Premise Without Warrant', 'Search Of Premise Without Warrant'),
#  ...]

# %%
len(edges), len(set(edges))
# Out:
# (68687, 1881)

# %%
edge_counts = collections.Counter(edges)

# %%
len(edge_counts)
# Out:
# 1881

# %%
df_edges = pd.DataFrame.from_dict(edge_counts, columns=['Edge Frequency'], orient='index')

# %%
df_edges.head()
# Out:
#                                                     Edge Frequency
# (Unnecessary Display Of Weapon / Off Duty, Sear...              48
# (Search Of Premise Without Warrant, Inadequate ...             221
# (Inventory Procedures, Improper Search Of Person)               26
# (Improper Search Of Person, Improper Search Of ...            1260
# (Improper Search Of Person, Illegal Arrest / Fa...             221

# %%
df_edges.hist(bins=40, log=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efbca04ef28>]], dtype=object)

# %%
G = nx.Graph()

# %%
nodes = dict()

for row in set(edges):
    if row[0] not in nodes:
        nodes[row[0]] = len(nodes)
        G.add_node(nodes[row[0]], name=row[0])
    if row[1] not in nodes:
        nodes[row[1]] = len(nodes)
        G.add_node(nodes[row[1]], name=row[1])
    G.add_edge(nodes[row[0]], nodes[row[1]], weight=float(edge_counts[row]))

# %%
len(nodes)
# Out:
# 125

# %%
len(G.edges)
# Out:
# 1292

# %%
partition = community.best_partition(G, weight='weight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-d9214794cee4> in <module>
# ----> 1 partition = community.best_partition(G, weight='weight')
#
# AttributeError: module 'community' has no attribute 'best_partition'

# %%
size = float(len(set(partition.values())))
pos = nx.spring_layout(G)
count = 0.
for com in set(partition.values()) :
    count = count + 1.
    list_nodes = [nodes for nodes in partition.keys()
                                if partition[nodes] == com]
    nx.draw_networkx_nodes(G, pos, list_nodes, node_size = 30,
                                node_color = str(count / size))


nx.draw_networkx_edges(G, pos, alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-4012e9e75c68> in <module>
# ----> 1 size = float(len(set(partition.values())))
#       2 pos = nx.spring_layout(G)
#       3 count = 0.
#       4 for com in set(partition.values()) :
#       5     count = count + 1.
#
# NameError: name 'partition' is not defined

# %%
community.modularity(partition, G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-8cba739fbccb> in <module>
# ----> 1 community.modularity(partition, G)
#
# AttributeError: module 'community' has no attribute 'modularity'

# %%
len(partition.values())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-80e4708aa63e> in <module>
# ----> 1 len(partition.values())
#
# NameError: name 'partition' is not defined

# %%
communities = { i : [] for i in range(0,40) }

[communities[community].append(G.node[node]['name']) for node, community in enumerate(partition.values())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-7acbddcfed16> in <module>
#       1 communities = { i : [] for i in range(0,40) }
#       2
# ----> 3 [communities[community].append(G.node[node]['name']) for node, community in enumerate(partition.values())]
#
# NameError: name 'partition' is not defined

# %%
communities

# %%
community
# Out:
# <module 'community' from '/home/liankeqin/.local/lib/python3.6/site-packages/community/__init__.py'>
